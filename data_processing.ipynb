# %%
pip install split-folders tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\python38\python.exe -m pip install --upgrade pip' command.

# %%
import splitfolders

# %%
input_folder = "Classification/input_dataset"
output = "Classification/processed_data"
splitfolders.ratio(input_folder, output, seed=42, ratio=(.6, .2, .2))
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 1 files [00:00,  4.06 files/s]
# Copying files: 6 files [00:00, 20.33 files/s]
# Copying files: 11 files [00:00, 28.65 files/s]
# Copying files: 17 files [00:00, 36.74 files/s]
# Copying files: 22 files [00:00, 33.01 files/s]
# Copying files: 26 files [00:00, 28.25 files/s]
# Copying files: 31 files [00:01, 33.24 files/s]
# Copying files: 35 files [00:01, 33.78 files/s]
# Copying files: 40 files [00:01, 37.02 files/s]
# Copying files: 44 files [00:01, 20.65 files/s]
# Copying files: 48 files [00:01, 22.93 files/s]
# Copying files: 54 files [00:01, 29.67 files/s]
# Copying files: 61 files [00:02, 37.09 files/s]
# Copying files: 67 files [00:02, 40.38 files/s]
# Copying files: 73 files [00:02, 42.75 files/s]
# Copying files: 78 files [00:02, 44.06 files/s]
# Copying files: 85 files [00:02, 46.77 files/s]
# Copying files: 91 files [00:02, 44.59 files/s]
# Copying files: 97 files [00:02, 46.34 files/s]
# ...

# %%
help(splitfolders.ratio)
# Out:
# Help on function ratio in module splitfolders.split:
#
# ratio(input, output='output', seed=1337, ratio=(0.8, 0.1, 0.1), group_prefix=None)
